# %%
import pandas as pd

prices = [2999,15999,52999,4999,1999]
products = ['Wireless Earbuds','Smartphone','Laptop','SmartWatch','Bluetooth Speaker']

product_prices = pd.Series(prices,index=products)
print(product_prices)
# Out:
# Wireless Earbuds      2999
# Smartphone           15999
# Laptop               52999
# SmartWatch            4999
# Bluetooth Speaker     1999
# dtype: int64

# %%
print('Mean:', product_prices.mean())
print('Sum:', product_prices.sum())
print('Max:', product_prices.max())
print('Min:', product_prices.min())
# Out:
# Mean: 15799.0
# Sum: 78995
# Max: 52999
# Min: 1999

# %%
print(product_prices.head(3))
print(product_prices.tail(2))
# Out:
# Wireless Earbuds     2999
# Smartphone          15999
# Laptop              52999
# dtype: int64
# SmartWatch           4999
# Bluetooth Speaker    1999
# dtype: int64

# %%
print(product_prices.apply(lambda x: f'${x+(x*0.18)}'))
print(product_prices.map(lambda x:f'${x}.00'))
# Out:
# Wireless Earbuds     $3538.8199999999997
# Smartphone                     $18878.82
# Laptop                         $62538.82
# SmartWatch                      $5898.82
# Bluetooth Speaker               $2358.82
# dtype: object
# Wireless Earbuds      $2999.00
# Smartphone           $15999.00
# Laptop               $52999.00
# SmartWatch            $4999.00
# Bluetooth Speaker     $1999.00
# dtype: object

# %%
print(product_prices.sort_values())
print(product_prices.sort_index())
print(product_prices.sort_values(ascending=False))
print(product_prices.value_counts())
# Out:
# Bluetooth Speaker     1999
# Wireless Earbuds      2999
# SmartWatch            4999
# Smartphone           15999
# Laptop               52999
# dtype: int64
# Bluetooth Speaker     1999
# Laptop               52999
# SmartWatch            4999
# Smartphone           15999
# Wireless Earbuds      2999
# dtype: int64
# Laptop               52999
# Smartphone           15999
# SmartWatch            4999
# Wireless Earbuds      2999
# Bluetooth Speaker     1999
# dtype: int64
# 2999     1
# 15999    1
# 52999    1
# 4999     1
# 1999     1
# Name: count, dtype: int64

# %%
data = {
    'Product' : ['Wireless Earbuds','Smartphone','Laptop','SmartWatch','Bluetooth Speaker'],
    'Brand' : ['SoundMax','Technova','ByteCore','TimeTrack','EchoBoom'],
    'Price' : [2999,15999,52999,4999,5678],
    'Stock' : [50,30,20,40,60],
    'BestSeller' : [True,False,False,True,True]
}
df = pd.DataFrame(data)
print(df)
# Out:
#              Product      Brand  Price  Stock  BestSeller
# 0   Wireless Earbuds   SoundMax   2999     50        True
# 1         Smartphone   Technova  15999     30       False
# 2             Laptop   ByteCore  52999     20       False
# 3         SmartWatch  TimeTrack   4999     40        True
# 4  Bluetooth Speaker   EchoBoom   5678     60        True

# %%
from google.colab import files

uploaded = files.upload()

df = pd.read_excel('products_50_rows.xlsx')
print(df)
# Out:
#               Product      Brand  Price  Stock  BestSeller
# 0             Monitor   EchoBoom  43625    182        True
# 1   Bluetooth Speaker   SoundMax  10067    117        True
# 2              Laptop    SkyLink  65982    152       False
# 3              Webcam   EchoBoom  44852    115       False
# 4          Headphones   TechNova  53477     61       False
# 5              Webcam    SkyLink  48180    104       False
# 6           USB Cable   ByteCore  45096     63       False
# 7    Wireless Earbuds   ByteCore  45812     82        True
# 8           USB Cable      VoltX  77217    173        True
# 9          Hard Drive    SkyLink  65798    146        True
# 10             Laptop    NextGen  53616     24       False
# 11             Laptop   SoundMax  15764    116        True
# 12                SSD    NextGen  32934     81       False
# 13             Tablet   SoundMax   2826     42        True
# 14            Printer   PixelPro  79898     63        True
# 15             Router   EchoBoom  74190    127        True
# 16             Router    SkyLink  63027     66        True
# 17              Drone    SkyLink  21901    109        True
# 18          Projector      VoltX  72679     81        True
# 19             Webcam      VoltX  17138     83       False
# 20          Projector   TechNova  57509     73       False
# 21            Monitor    SkyLink  73788     52        True
# 22         Smartwatch   NovaTech   1559    192       False
# 23       Gaming Mouse  TimeTrack   2098     42        True
# 24         Headphones   TechNova   9591     20       False
# 25          Projector   PixelPro  54897    157       False
# 26         Power Bank   EchoBoom   8318    187        True
# 27         Smartphone      VoltX  63764     24        True
# 28                SSD   NovaTech  53013     25       False
# 29   Wireless Earbuds   PixelPro  39122     30       False
# 30             Webcam   NovaTech  63799     28        True
# 31             Laptop   PixelPro  26906     24        True
# 32       Gaming Mouse  TimeTrack  41963    101       False
# 33              Drone   SoundMax   3968    135       False
# 34         Smartphone  TimeTrack  35150     44       False
# 35  Bluetooth Speaker   TechNova   4649     56       False
# 36   Wireless Earbuds    NextGen  27632     56       False
# 37              Drone   SoundMax  23211    184       False
# 38             Tablet    NextGen  10142     77        True
# 39         Hard Drive    NextGen  72236     34        True
# 40         Hard Drive    SkyLink   8179     63        True
# 41         Microphone   ByteCore  48817    138        True
# 42          Projector   PixelPro  19005    136       False
# 43            Monitor   ByteCore  14169    145       False
# 44             Laptop   ByteCore   4447     70        True
# 45         Headphones   TechNova  64078    143        True
# 46         Smartphone  TimeTrack  46200     94        True
# 47                SSD      VoltX   1266      5        True
# 48            Printer    NextGen  17706    169        True
# 49         Smartphone      VoltX  63451    130       False

# %%
print(df.shape)
print(df.columns)
print(df.info())
# Out:
# (50, 5)
# Index(['Product', 'Brand', 'Price', 'Stock', 'BestSeller'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     50 non-null     object
#  1   Brand       50 non-null     object
#  2   Price       50 non-null     int64
#  3   Stock       50 non-null     int64
#  4   BestSeller  50 non-null     bool
# dtypes: bool(1), int64(2), object(2)
# memory usage: 1.7+ KB
# None

# %%
print(df.head(5))
print(df.tail(5))
# Out:
#              Product     Brand  Price  Stock  BestSeller
# 0            Monitor  EchoBoom  43625    182        True
# 1  Bluetooth Speaker  SoundMax  10067    117        True
# 2             Laptop   SkyLink  65982    152       False
# 3             Webcam  EchoBoom  44852    115       False
# 4         Headphones  TechNova  53477     61       False
#        Product      Brand  Price  Stock  BestSeller
# 45  Headphones   TechNova  64078    143        True
# 46  Smartphone  TimeTrack  46200     94        True
# 47         SSD      VoltX   1266      5        True
# 48     Printer    NextGen  17706    169        True
# 49  Smartphone      VoltX  63451    130       False

# %%
print(df.iloc[0])
print(df.iloc[1])

print(df['Product'])
# Out:
# Product        Monitor
# Brand         EchoBoom
# Price            43625
# Stock              182
# BestSeller        True
# Name: 0, dtype: object
# Product       Bluetooth Speaker
# Brand                  SoundMax
# Price                     10067
# Stock                       117
# BestSeller                 True
# Name: 1, dtype: object
# 0               Monitor
# 1     Bluetooth Speaker
# 2                Laptop
# 3                Webcam
# 4            Headphones
# 5                Webcam
# 6             USB Cable
# 7      Wireless Earbuds
# 8             USB Cable
# 9            Hard Drive
# 10               Laptop
# 11               Laptop
# 12                  SSD
# 13               Tablet
# 14              Printer
# 15               Router
# 16               Router
# 17                Drone
# 18            Projector
# 19               Webcam
# 20            Projector
# 21              Monitor
# 22           Smartwatch
# 23         Gaming Mouse
# 24           Headphones
# 25            Projector
# 26           Power Bank
# 27           Smartphone
# 28                  SSD
# 29     Wireless Earbuds
# 30               Webcam
# 31               Laptop
# 32         Gaming Mouse
# 33                Drone
# 34           Smartphone
# 35    Bluetooth Speaker
# 36     Wireless Earbuds
# 37                Drone
# 38               Tablet
# 39           Hard Drive
# 40           Hard Drive
# 41           Microphone
# 42            Projector
# 43              Monitor
# 44               Laptop
# 45           Headphones
# 46           Smartphone
# 47                  SSD
# 48              Printer
# 49           Smartphone
# Name: Product, dtype: object

# %%
print(df)
print(df.loc[2,'Brand'])
print(df.loc[3,'Product'])
print(df.loc[12,'Stock'])

print(df.iloc[4,0])
print(df.iloc[2,1])
print(df.iloc[3,3])
# Out:
#               Product      Brand  Price  Stock  BestSeller
# 0             Monitor   EchoBoom  43625    182        True
# 1   Bluetooth Speaker   SoundMax  10067    117        True
# 2              Laptop    SkyLink  65982    152       False
# 3              Webcam   EchoBoom  44852    115       False
# 4          Headphones   TechNova  53477     61       False
# 5              Webcam    SkyLink  48180    104       False
# 6           USB Cable   ByteCore  45096     63       False
# 7    Wireless Earbuds   ByteCore  45812     82        True
# 8           USB Cable      VoltX  77217    173        True
# 9          Hard Drive    SkyLink  65798    146        True
# 10             Laptop    NextGen  53616     24       False
# 11             Laptop   SoundMax  15764    116        True
# 12                SSD    NextGen  32934     81       False
# 13             Tablet   SoundMax   2826     42        True
# 14            Printer   PixelPro  79898     63        True
# 15             Router   EchoBoom  74190    127        True
# 16             Router    SkyLink  63027     66        True
# 17              Drone    SkyLink  21901    109        True
# 18          Projector      VoltX  72679     81        True
# 19             Webcam      VoltX  17138     83       False
# 20          Projector   TechNova  57509     73       False
# 21            Monitor    SkyLink  73788     52        True
# 22         Smartwatch   NovaTech   1559    192       False
# 23       Gaming Mouse  TimeTrack   2098     42        True
# 24         Headphones   TechNova   9591     20       False
# 25          Projector   PixelPro  54897    157       False
# 26         Power Bank   EchoBoom   8318    187        True
# 27         Smartphone      VoltX  63764     24        True
# 28                SSD   NovaTech  53013     25       False
# 29   Wireless Earbuds   PixelPro  39122     30       False
# 30             Webcam   NovaTech  63799     28        True
# 31             Laptop   PixelPro  26906     24        True
# 32       Gaming Mouse  TimeTrack  41963    101       False
# 33              Drone   SoundMax   3968    135       False
# 34         Smartphone  TimeTrack  35150     44       False
# 35  Bluetooth Speaker   TechNova   4649     56       False
# 36   Wireless Earbuds    NextGen  27632     56       False
# 37              Drone   SoundMax  23211    184       False
# 38             Tablet    NextGen  10142     77        True
# 39         Hard Drive    NextGen  72236     34        True
# 40         Hard Drive    SkyLink   8179     63        True
# 41         Microphone   ByteCore  48817    138        True
# 42          Projector   PixelPro  19005    136       False
# 43            Monitor   ByteCore  14169    145       False
# 44             Laptop   ByteCore   4447     70        True
# 45         Headphones   TechNova  64078    143        True
# 46         Smartphone  TimeTrack  46200     94        True
# 47                SSD      VoltX   1266      5        True
# 48            Printer    NextGen  17706    169        True
# 49         Smartphone      VoltX  63451    130       False
# SkyLink
# Webcam
# 81
# Headphones
# SkyLink
# 115

# %%
df_dropped = df.drop(columns=['Stock'])
#df.drop(columns=['Stock],inplace=True)
print(df_dropped)
# Out:
#               Product      Brand  Price  BestSeller
# 0             Monitor   EchoBoom  43625        True
# 1   Bluetooth Speaker   SoundMax  10067        True
# 2              Laptop    SkyLink  65982       False
# 3              Webcam   EchoBoom  44852       False
# 4          Headphones   TechNova  53477       False
# 5              Webcam    SkyLink  48180       False
# 6           USB Cable   ByteCore  45096       False
# 7    Wireless Earbuds   ByteCore  45812        True
# 8           USB Cable      VoltX  77217        True
# 9          Hard Drive    SkyLink  65798        True
# 10             Laptop    NextGen  53616       False
# 11             Laptop   SoundMax  15764        True
# 12                SSD    NextGen  32934       False
# 13             Tablet   SoundMax   2826        True
# 14            Printer   PixelPro  79898        True
# 15             Router   EchoBoom  74190        True
# 16             Router    SkyLink  63027        True
# 17              Drone    SkyLink  21901        True
# 18          Projector      VoltX  72679        True
# 19             Webcam      VoltX  17138       False
# 20          Projector   TechNova  57509       False
# 21            Monitor    SkyLink  73788        True
# 22         Smartwatch   NovaTech   1559       False
# 23       Gaming Mouse  TimeTrack   2098        True
# 24         Headphones   TechNova   9591       False
# 25          Projector   PixelPro  54897       False
# 26         Power Bank   EchoBoom   8318        True
# 27         Smartphone      VoltX  63764        True
# 28                SSD   NovaTech  53013       False
# 29   Wireless Earbuds   PixelPro  39122       False
# 30             Webcam   NovaTech  63799        True
# 31             Laptop   PixelPro  26906        True
# 32       Gaming Mouse  TimeTrack  41963       False
# 33              Drone   SoundMax   3968       False
# 34         Smartphone  TimeTrack  35150       False
# 35  Bluetooth Speaker   TechNova   4649       False
# 36   Wireless Earbuds    NextGen  27632       False
# 37              Drone   SoundMax  23211       False
# 38             Tablet    NextGen  10142        True
# 39         Hard Drive    NextGen  72236        True
# 40         Hard Drive    SkyLink   8179        True
# 41         Microphone   ByteCore  48817        True
# 42          Projector   PixelPro  19005       False
# 43            Monitor   ByteCore  14169       False
# 44             Laptop   ByteCore   4447        True
# 45         Headphones   TechNova  64078        True
# 46         Smartphone  TimeTrack  46200        True
# 47                SSD      VoltX   1266        True
# 48            Printer    NextGen  17706        True
# 49         Smartphone      VoltX  63451       False

# %%
df_renamed = df.rename(columns={'Price': 'Cost'})
print(df_renamed)
#df.rename(columns={'Product': 'Product name'}, inplace=True)
# Out:
#               Product      Brand   Cost  Stock  BestSeller
# 0             Monitor   EchoBoom  43625    182        True
# 1   Bluetooth Speaker   SoundMax  10067    117        True
# 2              Laptop    SkyLink  65982    152       False
# 3              Webcam   EchoBoom  44852    115       False
# 4          Headphones   TechNova  53477     61       False
# 5              Webcam    SkyLink  48180    104       False
# 6           USB Cable   ByteCore  45096     63       False
# 7    Wireless Earbuds   ByteCore  45812     82        True
# 8           USB Cable      VoltX  77217    173        True
# 9          Hard Drive    SkyLink  65798    146        True
# 10             Laptop    NextGen  53616     24       False
# 11             Laptop   SoundMax  15764    116        True
# 12                SSD    NextGen  32934     81       False
# 13             Tablet   SoundMax   2826     42        True
# 14            Printer   PixelPro  79898     63        True
# 15             Router   EchoBoom  74190    127        True
# 16             Router    SkyLink  63027     66        True
# 17              Drone    SkyLink  21901    109        True
# 18          Projector      VoltX  72679     81        True
# 19             Webcam      VoltX  17138     83       False
# 20          Projector   TechNova  57509     73       False
# 21            Monitor    SkyLink  73788     52        True
# 22         Smartwatch   NovaTech   1559    192       False
# 23       Gaming Mouse  TimeTrack   2098     42        True
# 24         Headphones   TechNova   9591     20       False
# 25          Projector   PixelPro  54897    157       False
# 26         Power Bank   EchoBoom   8318    187        True
# 27         Smartphone      VoltX  63764     24        True
# 28                SSD   NovaTech  53013     25       False
# 29   Wireless Earbuds   PixelPro  39122     30       False
# 30             Webcam   NovaTech  63799     28        True
# 31             Laptop   PixelPro  26906     24        True
# 32       Gaming Mouse  TimeTrack  41963    101       False
# 33              Drone   SoundMax   3968    135       False
# 34         Smartphone  TimeTrack  35150     44       False
# 35  Bluetooth Speaker   TechNova   4649     56       False
# 36   Wireless Earbuds    NextGen  27632     56       False
# 37              Drone   SoundMax  23211    184       False
# 38             Tablet    NextGen  10142     77        True
# 39         Hard Drive    NextGen  72236     34        True
# 40         Hard Drive    SkyLink   8179     63        True
# 41         Microphone   ByteCore  48817    138        True
# 42          Projector   PixelPro  19005    136       False
# 43            Monitor   ByteCore  14169    145       False
# 44             Laptop   ByteCore   4447     70        True
# 45         Headphones   TechNova  64078    143        True
# 46         Smartphone  TimeTrack  46200     94        True
# 47                SSD      VoltX   1266      5        True
# 48            Printer    NextGen  17706    169        True
# 49         Smartphone      VoltX  63451    130       False

# %%
print(df)
print(df.loc[df['BestSeller']==True])
print(df.loc[df['Stock']<40])
print(df.loc[df['Price']<10000])
# Out:
#               Product      Brand  Price  Stock  BestSeller
# 0             Monitor   EchoBoom  43625    182        True
# 1   Bluetooth Speaker   SoundMax  10067    117        True
# 2              Laptop    SkyLink  65982    152       False
# 3              Webcam   EchoBoom  44852    115       False
# 4          Headphones   TechNova  53477     61       False
# 5              Webcam    SkyLink  48180    104       False
# 6           USB Cable   ByteCore  45096     63       False
# 7    Wireless Earbuds   ByteCore  45812     82        True
# 8           USB Cable      VoltX  77217    173        True
# 9          Hard Drive    SkyLink  65798    146        True
# 10             Laptop    NextGen  53616     24       False
# 11             Laptop   SoundMax  15764    116        True
# 12                SSD    NextGen  32934     81       False
# 13             Tablet   SoundMax   2826     42        True
# 14            Printer   PixelPro  79898     63        True
# 15             Router   EchoBoom  74190    127        True
# 16             Router    SkyLink  63027     66        True
# 17              Drone    SkyLink  21901    109        True
# 18          Projector      VoltX  72679     81        True
# 19             Webcam      VoltX  17138     83       False
# 20          Projector   TechNova  57509     73       False
# 21            Monitor    SkyLink  73788     52        True
# 22         Smartwatch   NovaTech   1559    192       False
# 23       Gaming Mouse  TimeTrack   2098     42        True
# 24         Headphones   TechNova   9591     20       False
# 25          Projector   PixelPro  54897    157       False
# 26         Power Bank   EchoBoom   8318    187        True
# 27         Smartphone      VoltX  63764     24        True
# 28                SSD   NovaTech  53013     25       False
# 29   Wireless Earbuds   PixelPro  39122     30       False
# 30             Webcam   NovaTech  63799     28        True
# 31             Laptop   PixelPro  26906     24        True
# 32       Gaming Mouse  TimeTrack  41963    101       False
# 33              Drone   SoundMax   3968    135       False
# 34         Smartphone  TimeTrack  35150     44       False
# 35  Bluetooth Speaker   TechNova   4649     56       False
# 36   Wireless Earbuds    NextGen  27632     56       False
# 37              Drone   SoundMax  23211    184       False
# 38             Tablet    NextGen  10142     77        True
# 39         Hard Drive    NextGen  72236     34        True
# 40         Hard Drive    SkyLink   8179     63        True
# 41         Microphone   ByteCore  48817    138        True
# 42          Projector   PixelPro  19005    136       False
# 43            Monitor   ByteCore  14169    145       False
# 44             Laptop   ByteCore   4447     70        True
# 45         Headphones   TechNova  64078    143        True
# 46         Smartphone  TimeTrack  46200     94        True
# 47                SSD      VoltX   1266      5        True
# 48            Printer    NextGen  17706    169        True
# 49         Smartphone      VoltX  63451    130       False
#               Product      Brand  Price  Stock  BestSeller
# 0             Monitor   EchoBoom  43625    182        True
# 1   Bluetooth Speaker   SoundMax  10067    117        True
# 7    Wireless Earbuds   ByteCore  45812     82        True
# 8           USB Cable      VoltX  77217    173        True
# 9          Hard Drive    SkyLink  65798    146        True
# 11             Laptop   SoundMax  15764    116        True
# 13             Tablet   SoundMax   2826     42        True
# 14            Printer   PixelPro  79898     63        True
# 15             Router   EchoBoom  74190    127        True
# 16             Router    SkyLink  63027     66        True
# 17              Drone    SkyLink  21901    109        True
# 18          Projector      VoltX  72679     81        True
# 21            Monitor    SkyLink  73788     52        True
# 23       Gaming Mouse  TimeTrack   2098     42        True
# 26         Power Bank   EchoBoom   8318    187        True
# 27         Smartphone      VoltX  63764     24        True
# 30             Webcam   NovaTech  63799     28        True
# 31             Laptop   PixelPro  26906     24        True
# 38             Tablet    NextGen  10142     77        True
# 39         Hard Drive    NextGen  72236     34        True
# 40         Hard Drive    SkyLink   8179     63        True
# 41         Microphone   ByteCore  48817    138        True
# 44             Laptop   ByteCore   4447     70        True
# 45         Headphones   TechNova  64078    143        True
# 46         Smartphone  TimeTrack  46200     94        True
# 47                SSD      VoltX   1266      5        True
# 48            Printer    NextGen  17706    169        True
#              Product     Brand  Price  Stock  BestSeller
# 10            Laptop   NextGen  53616     24       False
# 24        Headphones  TechNova   9591     20       False
# 27        Smartphone     VoltX  63764     24        True
# 28               SSD  NovaTech  53013     25       False
# 29  Wireless Earbuds  PixelPro  39122     30       False
# 30            Webcam  NovaTech  63799     28        True
# 31            Laptop  PixelPro  26906     24        True
# 39        Hard Drive   NextGen  72236     34        True
# 47               SSD     VoltX   1266      5        True
#               Product      Brand  Price  Stock  BestSeller
# 13             Tablet   SoundMax   2826     42        True
# 22         Smartwatch   NovaTech   1559    192       False
# 23       Gaming Mouse  TimeTrack   2098     42        True
# 24         Headphones   TechNova   9591     20       False
# 26         Power Bank   EchoBoom   8318    187        True
# 33              Drone   SoundMax   3968    135       False
# 35  Bluetooth Speaker   TechNova   4649     56       False
# 40         Hard Drive    SkyLink   8179     63        True
# 44             Laptop   ByteCore   4447     70        True
# 47                SSD      VoltX   1266      5        True

# %%
df_grouped = df.groupby('Brand').agg({'Price': 'mean', 'Stock': 'sum'})
print(df_grouped)

grouped = df.groupby('Brand').agg({'Price': ['mean','max','min','sum']})
print(grouped)

grouped = df.groupby('Brand')['Price'].mean()
print(grouped)
# Out:
#                   Price  Stock
# Brand
# ByteCore   31668.200000    498
# EchoBoom   42746.250000    611
# NextGen    35711.000000    441
# NovaTech   39457.000000    245
# PixelPro   43965.600000    410
# SkyLink    49550.714286    692
# SoundMax   11167.200000    594
# TechNova   37860.800000    353
# TimeTrack  31352.750000    281
# VoltX      49252.500000    496
#                   Price
#                    mean    max    min     sum
# Brand
# ByteCore   31668.200000  48817   4447  158341
# EchoBoom   42746.250000  74190   8318  170985
# NextGen    35711.000000  72236  10142  214266
# NovaTech   39457.000000  63799   1559  118371
# PixelPro   43965.600000  79898  19005  219828
# SkyLink    49550.714286  73788   8179  346855
# SoundMax   11167.200000  23211   2826   55836
# TechNova   37860.800000  64078   4649  189304
# TimeTrack  31352.750000  46200   2098  125411
# VoltX      49252.500000  77217   1266  295515
# Brand
# ByteCore     31668.200000
# EchoBoom     42746.250000
# NextGen      35711.000000
# NovaTech     39457.000000
# PixelPro     43965.600000
# SkyLink      49550.714286
# SoundMax     11167.200000
# TechNova     37860.800000
# TimeTrack    31352.750000
# VoltX        49252.500000
# Name: Price, dtype: float64

# %%
data2 = {
    'Brand' : ['SoundMax','Technova','ByteCore','TimeTrack','EchoBoom'],
    'Rating' : [4.2,4.5,4.0,4.1,3.9],
    'discount' : [28,40,16,10,5]
}
df_ratings = pd.DataFrame(data2)
print(df_ratings)
# Out:
#        Brand  Rating  discount
# 0   SoundMax     4.2        28
# 1   Technova     4.5        40
# 2   ByteCore     4.0        16
# 3  TimeTrack     4.1        10
# 4   EchoBoom     3.9         5

# %%
new_data = {
    'Product' : ['Tablet'],
    'Brand' : ['SmartWare'],
    'Price' : [12999],
    'Stock' : [25],
    'BestSeller' : [True]
}
df_new = pd.DataFrame(new_data)
print(df_new)
# Out:
#   Product      Brand  Price  Stock  BestSeller
# 0  Tablet  SmartWare  12999     25        True

# %%
df_concat = pd.concat([df,df_new],ignore_index=True)
print('Concatenated DataFrame:\n',df_concat)
# Out:
# Concatenated DataFrame:
#                Product      Brand  Price  Stock  BestSeller
# 0             Monitor   EchoBoom  43625    182        True
# 1   Bluetooth Speaker   SoundMax  10067    117        True
# 2              Laptop    SkyLink  65982    152       False
# 3              Webcam   EchoBoom  44852    115       False
# 4          Headphones   TechNova  53477     61       False
# 5              Webcam    SkyLink  48180    104       False
# 6           USB Cable   ByteCore  45096     63       False
# 7    Wireless Earbuds   ByteCore  45812     82        True
# 8           USB Cable      VoltX  77217    173        True
# 9          Hard Drive    SkyLink  65798    146        True
# 10             Laptop    NextGen  53616     24       False
# 11             Laptop   SoundMax  15764    116        True
# 12                SSD    NextGen  32934     81       False
# 13             Tablet   SoundMax   2826     42        True
# 14            Printer   PixelPro  79898     63        True
# 15             Router   EchoBoom  74190    127        True
# 16             Router    SkyLink  63027     66        True
# 17              Drone    SkyLink  21901    109        True
# 18          Projector      VoltX  72679     81        True
# 19             Webcam      VoltX  17138     83       False
# 20          Projector   TechNova  57509     73       False
# 21            Monitor    SkyLink  73788     52        True
# 22         Smartwatch   NovaTech   1559    192       False
# 23       Gaming Mouse  TimeTrack   2098     42        True
# 24         Headphones   TechNova   9591     20       False
# 25          Projector   PixelPro  54897    157       False
# 26         Power Bank   EchoBoom   8318    187        True
# 27         Smartphone      VoltX  63764     24        True
# 28                SSD   NovaTech  53013     25       False
# 29   Wireless Earbuds   PixelPro  39122     30       False
# 30             Webcam   NovaTech  63799     28        True
# 31             Laptop   PixelPro  26906     24        True
# 32       Gaming Mouse  TimeTrack  41963    101       False
# 33              Drone   SoundMax   3968    135       False
# 34         Smartphone  TimeTrack  35150     44       False
# 35  Bluetooth Speaker   TechNova   4649     56       False
# 36   Wireless Earbuds    NextGen  27632     56       False
# 37              Drone   SoundMax  23211    184       False
# 38             Tablet    NextGen  10142     77        True
# 39         Hard Drive    NextGen  72236     34        True
# 40         Hard Drive    SkyLink   8179     63        True
# 41         Microphone   ByteCore  48817    138        True
# 42          Projector   PixelPro  19005    136       False
# 43            Monitor   ByteCore  14169    145       False
# 44             Laptop   ByteCore   4447     70        True
# 45         Headphones   TechNova  64078    143        True
# 46         Smartphone  TimeTrack  46200     94        True
# 47                SSD      VoltX   1266      5        True
# 48            Printer    NextGen  17706    169        True
# 49         Smartphone      VoltX  63451    130       False
# 50             Tablet  SmartWare  12999     25        True
